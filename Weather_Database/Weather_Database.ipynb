# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the random module.
import random

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8e64bbb13d345365589760fb5da0e18e

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# create the city list
cities = []
# Identify the nearest city using citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the # of cities in the list
len(cities)
# Out:
# 708

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
     # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
     # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_wdescription = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_wdescription,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | nanortalik
# Processing Record 2 of Set 15 | cidreira
# Processing Record 3 of Set 15 | rikitea
# Processing Record 4 of Set 15 | tabou
# Processing Record 5 of Set 15 | carnarvon
# Processing Record 6 of Set 15 | ushuaia
# Processing Record 7 of Set 15 | norman wells
# Processing Record 8 of Set 15 | bardiyah
# Processing Record 9 of Set 15 | mataura
# Processing Record 10 of Set 15 | magadan
# Processing Record 11 of Set 15 | uhlove
# Processing Record 12 of Set 15 | chuy
# Processing Record 13 of Set 15 | chapais
# Processing Record 14 of Set 15 | coxim
# Processing Record 15 of Set 15 | tasiilaq
# Processing Record 16 of Set 15 | punta arenas
# Processing Record 17 of Set 15 | kapaa
# Processing Record 18 of Set 15 | hilo
# Processing Record 19 of Set 15 | namibe
# Processing Record 20 of Set 15 | bambous virieux
# Processing Record 21 of Set 15 | narsaq
# Processing Record 22 of Set 15 | nikolskoye
# Processing Record 23 of Set 15 | kavaratti
# Processing Record 24 of Set 15 | busselton
# Processing Record 25 of Set 15 | georgetown
# Processing Record 26 of Set 15 | orlik
# Processing Record 27 of Set 15 | kamenka
# Processing Record 28 of Set 15 | terrasini
# Processing Record 29 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 30 of Set 15 | kodiak
# Processing Record 31 of Set 15 | bengkulu
# Processing Record 32 of Set 15 | vao
# Processing Record 33 of Set 15 | hobart
# Processing Record 34 of Set 15 | klaksvik
# Processing Record 35 of Set 15 | thinadhoo
# Processing Record 36 of Set 15 | new norfolk
# Processing Record 37 of Set 15 | nyurba
# Processing Record 38 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 15 | upernavik
# Processing Record 40 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 15 | albany
# Processing Record 42 of Set 15 | ust-nera
# Processing Record 43 of Set 15 | hermanus
# Processing Record 44 of Set 15 | saint-philippe
# Processing Record 45 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 46 of Set 15 | palora
# Processing Record 47 of Set 15 | mahebourg
# Processing Record 48 of Set 15 | saldanha
# Processing Record 49 of Set 15 | alofi
# Processing Record 50 of Set 15 | vaini
# Processing Record 1 of Set 16 | avera
# Processing Record 2 of Set 16 | kangaatsiaq
# Processing Record 3 of Set 16 | lorengau
# Processing Record 4 of Set 16 | bluff
# Processing Record 5 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 16 | gazanjyk
# Processing Record 7 of Set 16 | salinopolis
# Processing Record 8 of Set 16 | lompoc
# Processing Record 9 of Set 16 | cape town
# Processing Record 10 of Set 16 | manacor
# Processing Record 11 of Set 16 | avarua
# Processing Record 12 of Set 16 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 16 | puerto colombia
# Processing Record 14 of Set 16 | victoria
# Processing Record 15 of Set 16 | dingle
# Processing Record 16 of Set 16 | port lincoln
# Processing Record 17 of Set 16 | turukhansk
# Processing Record 18 of Set 16 | caravelas
# Processing Record 19 of Set 16 | sao joao da barra
# Processing Record 20 of Set 16 | laguna
# Processing Record 21 of Set 16 | eyl
# Processing Record 22 of Set 16 | port elizabeth
# Processing Record 23 of Set 16 | umm lajj
# Processing Record 24 of Set 16 | iberia
# Processing Record 25 of Set 16 | airai
# Processing Record 26 of Set 16 | port alfred
# Processing Record 27 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 16 | assiniboia
# Processing Record 30 of Set 16 | vanderhoof
# Processing Record 31 of Set 16 | ketchikan
# Processing Record 32 of Set 16 | husavik
# Processing Record 33 of Set 16 | galle
# Processing Record 34 of Set 16 | beian
# Processing Record 35 of Set 16 | tulagi
# Processing Record 36 of Set 16 | daru
# Processing Record 37 of Set 16 | impfondo
# Processing Record 38 of Set 16 | ribeira grande
# Processing Record 39 of Set 16 | kaberamaido
# Processing Record 40 of Set 16 | atuona
# Processing Record 41 of Set 16 | bay-khaak
# Processing Record 42 of Set 16 | biak
# Processing Record 43 of Set 16 | geraldton
# Processing Record 44 of Set 16 | constitucion
# Processing Record 45 of Set 16 | lebu
# Processing Record 46 of Set 16 | salamanca
# Processing Record 47 of Set 16 | manta
# Processing Record 48 of Set 16 | souillac
# Processing Record 49 of Set 16 | half moon bay
# Processing Record 50 of Set 16 | iranshahr
# Processing Record 1 of Set 17 | zhanakorgan
# Processing Record 2 of Set 17 | horsham
# Processing Record 3 of Set 17 | namatanai
# Processing Record 4 of Set 17 | naryan-mar
# Processing Record 5 of Set 17 | yellowknife
# Processing Record 6 of Set 17 | vila velha
# Processing Record 7 of Set 17 | lavrentiya
# Processing Record 8 of Set 17 | cascais
# Processing Record 9 of Set 17 | guanica
# Processing Record 10 of Set 17 | saint anthony
# Processing Record 11 of Set 17 | lusambo
# Processing Record 12 of Set 17 | ahipara
# Processing Record 13 of Set 17 | butaritari
# Processing Record 14 of Set 17 | kunming
# Processing Record 15 of Set 17 | arraial do cabo
# Processing Record 16 of Set 17 | abha
# Processing Record 17 of Set 17 | kudahuvadhoo
# Processing Record 18 of Set 17 | barrow
# Processing Record 19 of Set 17 | kieta
# Processing Record 20 of Set 17 | esperance
# Processing Record 21 of Set 17 | batagay-alyta
# Processing Record 22 of Set 17 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 17 | mar del plata
# Processing Record 24 of Set 17 | ishigaki
# Processing Record 25 of Set 17 | khatanga
# Processing Record 26 of Set 17 | lakes entrance
# Processing Record 27 of Set 17 | thompson
# Processing Record 28 of Set 17 | kruisfontein
# Processing Record 29 of Set 17 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 17 | duku
# Processing Record 31 of Set 17 | longyearbyen
# Processing Record 32 of Set 17 | cherskiy
# Processing Record 33 of Set 17 | tuktoyaktuk
# Processing Record 34 of Set 17 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 17 | raton
# Processing Record 36 of Set 17 | iquique
# Processing Record 37 of Set 17 | ozernovskiy
# Processing Record 38 of Set 17 | saint george
# Processing Record 39 of Set 17 | east london
# Processing Record 40 of Set 17 | vanimo
# Processing Record 41 of Set 17 | tevaitoa
# Processing Record 42 of Set 17 | guerrero negro
# Processing Record 43 of Set 17 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 44 of Set 17 | siavonga
# Processing Record 45 of Set 17 | asau
# Processing Record 46 of Set 17 | castro
# Processing Record 47 of Set 17 | tupiza
# Processing Record 48 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 17 | erzin
# Processing Record 50 of Set 17 | lithakia
# Processing Record 1 of Set 18 | muyezerskiy
# Processing Record 2 of Set 18 | sao filipe
# Processing Record 3 of Set 18 | kibala
# Processing Record 4 of Set 18 | zhigansk
# Processing Record 5 of Set 18 | saskylakh
# Processing Record 6 of Set 18 | graham
# Processing Record 7 of Set 18 | tiksi
# Processing Record 8 of Set 18 | lagos
# Processing Record 9 of Set 18 | noshiro
# Processing Record 10 of Set 18 | eskasem
# City not found. Skipping...
# Processing Record 11 of Set 18 | xinyu
# Processing Record 12 of Set 18 | faanui
# Processing Record 13 of Set 18 | dakar
# Processing Record 14 of Set 18 | hithadhoo
# Processing Record 15 of Set 18 | taganak
# Processing Record 16 of Set 18 | magalia
# Processing Record 17 of Set 18 | cuencame
# Processing Record 18 of Set 18 | menongue
# Processing Record 19 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 18 | pevek
# Processing Record 21 of Set 18 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 18 | fortuna
# Processing Record 23 of Set 18 | korla
# Processing Record 24 of Set 18 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 18 | bubaque
# Processing Record 26 of Set 18 | dali
# Processing Record 27 of Set 18 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 18 | meulaboh
# Processing Record 29 of Set 18 | bagdarin
# Processing Record 30 of Set 18 | suntar
# Processing Record 31 of Set 18 | yulara
# Processing Record 32 of Set 18 | hutchinson
# Processing Record 33 of Set 18 | jamestown
# Processing Record 34 of Set 18 | atar
# Processing Record 35 of Set 18 | timra
# Processing Record 36 of Set 18 | huarmey
# Processing Record 37 of Set 18 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 18 | lagoa
# Processing Record 39 of Set 18 | vila
# Processing Record 40 of Set 18 | vardo
# Processing Record 41 of Set 18 | puerto ayora
# Processing Record 42 of Set 18 | isangel
# Processing Record 43 of Set 18 | quelimane
# Processing Record 44 of Set 18 | bredasdorp
# Processing Record 45 of Set 18 | aripuana
# Processing Record 46 of Set 18 | aybak
# City not found. Skipping...
# Processing Record 47 of Set 18 | latung
# Processing Record 48 of Set 18 | te anau
# Processing Record 49 of Set 18 | tukrah
# Processing Record 50 of Set 18 | amasya
# Processing Record 1 of Set 19 | fort walton beach
# Processing Record 2 of Set 19 | kushiro
# Processing Record 3 of Set 19 | luderitz
# Processing Record 4 of Set 19 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 19 | codrington
# Processing Record 6 of Set 19 | iracoubo
# Processing Record 7 of Set 19 | hobyo
# Processing Record 8 of Set 19 | coihaique
# Processing Record 9 of Set 19 | aklavik
# Processing Record 10 of Set 19 | ouahigouya
# Processing Record 11 of Set 19 | lakatoro
# Processing Record 12 of Set 19 | alice springs
# Processing Record 13 of Set 19 | usinsk
# Processing Record 14 of Set 19 | loding
# Processing Record 15 of Set 19 | salalah
# Processing Record 16 of Set 19 | faya
# Processing Record 17 of Set 19 | antofagasta
# Processing Record 18 of Set 19 | honiara
# Processing Record 19 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 19 | iqaluit
# Processing Record 21 of Set 19 | saint-joseph
# Processing Record 22 of Set 19 | bushehr
# Processing Record 23 of Set 19 | hasaki
# Processing Record 24 of Set 19 | maues
# Processing Record 25 of Set 19 | yar-sale
# Processing Record 26 of Set 19 | lodja
# Processing Record 27 of Set 19 | slave lake
# Processing Record 28 of Set 19 | buala
# Processing Record 29 of Set 19 | chokurdakh
# Processing Record 30 of Set 19 | verkhnyaya inta
# Processing Record 31 of Set 19 | mayo
# Processing Record 32 of Set 19 | oxford
# Processing Record 33 of Set 19 | fairview
# Processing Record 34 of Set 19 | omsukchan
# Processing Record 35 of Set 19 | mangan
# Processing Record 36 of Set 19 | ayan
# Processing Record 37 of Set 19 | broome
# Processing Record 38 of Set 19 | talnakh
# Processing Record 39 of Set 19 | tura
# Processing Record 40 of Set 19 | qaanaaq
# Processing Record 41 of Set 19 | seoul
# Processing Record 42 of Set 19 | gladstone
# Processing Record 43 of Set 19 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 19 | minbu
# Processing Record 45 of Set 19 | sept-iles
# Processing Record 46 of Set 19 | coquimbo
# Processing Record 47 of Set 19 | la ronge
# Processing Record 48 of Set 19 | camargo
# Processing Record 49 of Set 19 | arman
# Processing Record 50 of Set 19 | taraz
# Processing Record 1 of Set 20 | finschhafen
# Processing Record 2 of Set 20 | provideniya
# Processing Record 3 of Set 20 | ilulissat
# Processing Record 4 of Set 20 | cairns
# Processing Record 5 of Set 20 | manutuke
# Processing Record 6 of Set 20 | buariki
# City not found. Skipping...
# Processing Record 7 of Set 20 | ponta do sol
# Processing Record 8 of Set 20 | el viejo
# Processing Record 9 of Set 20 | cabo san lucas
# Processing Record 10 of Set 20 | high rock
# Processing Record 11 of Set 20 | acarau
# Processing Record 12 of Set 20 | port-gentil
# Processing Record 13 of Set 20 | tautira
# Processing Record 14 of Set 20 | baglan
# Processing Record 15 of Set 20 | newport
# Processing Record 16 of Set 20 | boysun
# Processing Record 17 of Set 20 | torbay
# Processing Record 18 of Set 20 | san patricio
# Processing Record 19 of Set 20 | harper
# Processing Record 20 of Set 20 | dunedin
# Processing Record 21 of Set 20 | jalu
# Processing Record 22 of Set 20 | magdagachi
# Processing Record 23 of Set 20 | aasiaat
# Processing Record 24 of Set 20 | alekseyevsk
# Processing Record 25 of Set 20 | manicore
# Processing Record 26 of Set 20 | batemans bay
# Processing Record 27 of Set 20 | merrill
# Processing Record 28 of Set 20 | port blair
# Processing Record 29 of Set 20 | tvardica
# City not found. Skipping...
# Processing Record 30 of Set 20 | ossora
# Processing Record 31 of Set 20 | mehamn
# Processing Record 32 of Set 20 | znamenskoye
# Processing Record 33 of Set 20 | flinders
# Processing Record 34 of Set 20 | preston
# Processing Record 35 of Set 20 | oil city
# Processing Record 36 of Set 20 | makakilo city
# Processing Record 37 of Set 20 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 20 | bouna
# Processing Record 39 of Set 20 | doha
# Processing Record 40 of Set 20 | suicheng
# Processing Record 41 of Set 20 | marsa matruh
# Processing Record 42 of Set 20 | tigil
# Processing Record 43 of Set 20 | olafsvik
# Processing Record 44 of Set 20 | axim
# Processing Record 45 of Set 20 | chandbali
# Processing Record 46 of Set 20 | mumford
# Processing Record 47 of Set 20 | sol-iletsk
# Processing Record 48 of Set 20 | vysokogornyy
# Processing Record 49 of Set 20 | uruzgan
# Processing Record 50 of Set 20 | forio
# Processing Record 1 of Set 21 | egvekinot
# Processing Record 2 of Set 21 | vilcun
# Processing Record 3 of Set 21 | baghdad
# Processing Record 4 of Set 21 | cap malheureux
# Processing Record 5 of Set 21 | aktash
# Processing Record 6 of Set 21 | lamu
# Processing Record 7 of Set 21 | kant
# Processing Record 8 of Set 21 | kachiry
# Processing Record 9 of Set 21 | askiz
# Processing Record 10 of Set 21 | cap-aux-meules
# Processing Record 11 of Set 21 | valday
# Processing Record 12 of Set 21 | price
# Processing Record 13 of Set 21 | hay river
# Processing Record 14 of Set 21 | moose jaw
# Processing Record 15 of Set 21 | tuatapere
# Processing Record 16 of Set 21 | hamadan
# Processing Record 17 of Set 21 | maceio
# Processing Record 18 of Set 21 | jiujiang
# Processing Record 19 of Set 21 | ponta delgada
# Processing Record 20 of Set 21 | naze
# Processing Record 21 of Set 21 | touros
# Processing Record 22 of Set 21 | dawson creek
# Processing Record 23 of Set 21 | bokspits
# City not found. Skipping...
# Processing Record 24 of Set 21 | mata
# Processing Record 25 of Set 21 | ferrol
# Processing Record 26 of Set 21 | kaitangata
# Processing Record 27 of Set 21 | isiro
# Processing Record 28 of Set 21 | maniitsoq
# Processing Record 29 of Set 21 | mount gambier
# Processing Record 30 of Set 21 | stokmarknes
# Processing Record 31 of Set 21 | qaqortoq
# Processing Record 32 of Set 21 | puerto escondido
# Processing Record 33 of Set 21 | kavieng
# Processing Record 34 of Set 21 | pitkyaranta
# Processing Record 35 of Set 21 | burica
# City not found. Skipping...
# Processing Record 36 of Set 21 | viedma
# Processing Record 37 of Set 21 | severo-kurilsk
# Processing Record 38 of Set 21 | tromso
# Processing Record 39 of Set 21 | mecca
# Processing Record 40 of Set 21 | rudnya
# Processing Record 41 of Set 21 | formoso do araguaia
# City not found. Skipping...
# Processing Record 42 of Set 21 | vallenar
# Processing Record 43 of Set 21 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 21 | clyde river
# Processing Record 45 of Set 21 | tilichiki
# Processing Record 46 of Set 21 | bam
# Processing Record 47 of Set 21 | grindavik
# Processing Record 48 of Set 21 | texarkana
# Processing Record 49 of Set 21 | bethel
# Processing Record 50 of Set 21 | qandala
# Processing Record 1 of Set 22 | la union
# Processing Record 2 of Set 22 | maunabo
# Processing Record 3 of Set 22 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 22 | cockburn town
# Processing Record 5 of Set 22 | abu jubayhah
# City not found. Skipping...
# Processing Record 6 of Set 22 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 22 | kot samaba
# Processing Record 8 of Set 22 | gulshat
# City not found. Skipping...
# Processing Record 9 of Set 22 | ancud
# Processing Record 10 of Set 22 | araguacu
# Processing Record 11 of Set 22 | knysna
# Processing Record 12 of Set 22 | krasnoselkup
# Processing Record 13 of Set 22 | homer
# Processing Record 14 of Set 22 | nelson bay
# Processing Record 15 of Set 22 | tyup
# Processing Record 16 of Set 22 | kem
# Processing Record 17 of Set 22 | irbeyskoye
# Processing Record 18 of Set 22 | fare
# Processing Record 19 of Set 22 | bontang
# Processing Record 20 of Set 22 | wajir
# Processing Record 21 of Set 22 | kozhevnikovo
# Processing Record 22 of Set 22 | marienburg
# Processing Record 23 of Set 22 | macaboboni
# City not found. Skipping...
# Processing Record 24 of Set 22 | mouzakion
# City not found. Skipping...
# Processing Record 25 of Set 22 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 22 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 22 | urubicha
# Processing Record 28 of Set 22 | shakhovskaya
# Processing Record 29 of Set 22 | sindou
# Processing Record 30 of Set 22 | kalaleh
# Processing Record 31 of Set 22 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 22 | garmsar
# Processing Record 33 of Set 22 | san francisco
# Processing Record 34 of Set 22 | mackay
# Processing Record 35 of Set 22 | riyadh
# Processing Record 36 of Set 22 | san fernando
# Processing Record 37 of Set 22 | guelengdeng
# City not found. Skipping...
# Processing Record 38 of Set 22 | kazerun
# Processing Record 39 of Set 22 | bathsheba
# Processing Record 40 of Set 22 | san andres
# Processing Record 41 of Set 22 | tvoroyri
# Processing Record 42 of Set 22 | san carlos de bariloche
# Processing Record 43 of Set 22 | kyren
# Processing Record 44 of Set 22 | abu dhabi
# Processing Record 45 of Set 22 | mandurah
# Processing Record 46 of Set 22 | hashtrud
# Processing Record 47 of Set 22 | inhambane
# Processing Record 48 of Set 22 | balsas
# Processing Record 49 of Set 22 | carutapera
# Processing Record 50 of Set 22 | lantawan
# Processing Record 1 of Set 23 | richards bay
# Processing Record 2 of Set 23 | pacific grove
# Processing Record 3 of Set 23 | zhuozhou
# City not found. Skipping...
# Processing Record 4 of Set 23 | lima
# Processing Record 5 of Set 23 | entre rios
# Processing Record 6 of Set 23 | ambon
# Processing Record 7 of Set 23 | los llanos de aridane
# Processing Record 8 of Set 23 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 23 | state college
# Processing Record 10 of Set 23 | dudinka
# Processing Record 11 of Set 23 | luoyang
# Processing Record 12 of Set 23 | churapcha
# Processing Record 13 of Set 23 | katiola
# Processing Record 14 of Set 23 | nouadhibou
# Processing Record 15 of Set 23 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 23 | sitka
# Processing Record 17 of Set 23 | bosilegrad
# Processing Record 18 of Set 23 | cervo
# Processing Record 19 of Set 23 | vostok
# Processing Record 20 of Set 23 | tucurui
# Processing Record 21 of Set 23 | chinhoyi
# Processing Record 22 of Set 23 | deputatskiy
# Processing Record 23 of Set 23 | saint pete beach
# Processing Record 24 of Set 23 | pisco
# Processing Record 25 of Set 23 | hambantota
# Processing Record 26 of Set 23 | tahoua
# Processing Record 27 of Set 23 | lata
# Processing Record 28 of Set 23 | betsiamites
# Processing Record 29 of Set 23 | kidal
# Processing Record 30 of Set 23 | broken hill
# Processing Record 31 of Set 23 | walvis bay
# Processing Record 32 of Set 23 | kununurra
# Processing Record 33 of Set 23 | yarada
# Processing Record 34 of Set 23 | matsanga
# City not found. Skipping...
# Processing Record 35 of Set 23 | praia da vitoria
# Processing Record 36 of Set 23 | gamba
# Processing Record 37 of Set 23 | safaga
# Processing Record 38 of Set 23 | padang
# Processing Record 39 of Set 23 | northam
# Processing Record 40 of Set 23 | cabedelo
# Processing Record 41 of Set 23 | vestmannaeyjar
# Processing Record 42 of Set 23 | schleiden
# Processing Record 43 of Set 23 | bull savanna
# Processing Record 44 of Set 23 | katsuura
# Processing Record 45 of Set 23 | miandrivazo
# Processing Record 46 of Set 23 | zwedru
# Processing Record 47 of Set 23 | benicarlo
# Processing Record 48 of Set 23 | itarema
# Processing Record 49 of Set 23 | mahina
# Processing Record 50 of Set 23 | waingapu
# Processing Record 1 of Set 24 | udimskiy
# Processing Record 2 of Set 24 | jiangyou
# Processing Record 3 of Set 24 | sawakin
# Processing Record 4 of Set 24 | astoria
# Processing Record 5 of Set 24 | sarh
# Processing Record 6 of Set 24 | tacoronte
# Processing Record 7 of Set 24 | great yarmouth
# Processing Record 8 of Set 24 | henties bay
# Processing Record 9 of Set 24 | fairbanks
# Processing Record 10 of Set 24 | tual
# Processing Record 11 of Set 24 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 24 | cayenne
# Processing Record 13 of Set 24 | patnos
# Processing Record 14 of Set 24 | alta floresta
# Processing Record 15 of Set 24 | semey
# Processing Record 16 of Set 24 | itoman
# Processing Record 17 of Set 24 | durango
# Processing Record 18 of Set 24 | sabang
# Processing Record 19 of Set 24 | clarence town
# Processing Record 20 of Set 24 | camacha
# Processing Record 21 of Set 24 | lampa
# Processing Record 22 of Set 24 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 24 | sola
# Processing Record 24 of Set 24 | lardos
# Processing Record 25 of Set 24 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 24 | gucheng
# Processing Record 27 of Set 24 | gotsu
# Processing Record 28 of Set 24 | necochea
# Processing Record 29 of Set 24 | palu
# Processing Record 30 of Set 24 | yarkovo
# Processing Record 31 of Set 24 | vinh
# Processing Record 32 of Set 24 | onega
# Processing Record 33 of Set 24 | north bend
# Processing Record 34 of Set 24 | rensvik
# Processing Record 35 of Set 24 | tungkang
# City not found. Skipping...
# Processing Record 36 of Set 24 | mirina
# City not found. Skipping...
# Processing Record 37 of Set 24 | biloela
# Processing Record 38 of Set 24 | oltu
# Processing Record 39 of Set 24 | hamilton
# Processing Record 40 of Set 24 | carmen
# Processing Record 41 of Set 24 | auki
# Processing Record 42 of Set 24 | dargaville
# Processing Record 43 of Set 24 | biltine
# Processing Record 44 of Set 24 | iwanai
# Processing Record 45 of Set 24 | adrar
# Processing Record 46 of Set 24 | liku
# Processing Record 47 of Set 24 | kota tinggi
# Processing Record 48 of Set 24 | polunochnoye
# Processing Record 49 of Set 24 | pleasant grove
# Processing Record 50 of Set 24 | xuddur
# Processing Record 1 of Set 25 | tazovskiy
# Processing Record 2 of Set 25 | vila franca do campo
# Processing Record 3 of Set 25 | portland
# Processing Record 4 of Set 25 | cururupu
# Processing Record 5 of Set 25 | copiapo
# Processing Record 6 of Set 25 | predivinsk
# Processing Record 7 of Set 25 | panguna
# Processing Record 8 of Set 25 | kerema
# Processing Record 9 of Set 25 | kurilsk
# Processing Record 10 of Set 25 | ugoofaaru
# Processing Record 11 of Set 25 | bistrica
# Processing Record 12 of Set 25 | chapada dos guimaraes
# Processing Record 13 of Set 25 | zhuhai
# Processing Record 14 of Set 25 | banamba
# Processing Record 15 of Set 25 | la asuncion
# Processing Record 16 of Set 25 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 25 | sechura
# Processing Record 18 of Set 25 | svetlyy
# Processing Record 19 of Set 25 | rio grande
# Processing Record 20 of Set 25 | sao miguel do araguaia
# Processing Record 21 of Set 25 | margate
# Processing Record 22 of Set 25 | borovoy
# Processing Record 23 of Set 25 | sorland
# Processing Record 24 of Set 25 | fukue
# Processing Record 25 of Set 25 | cerritos
# Processing Record 26 of Set 25 | kalianget
# Processing Record 27 of Set 25 | sal rei
# Processing Record 28 of Set 25 | porto novo
# Processing Record 29 of Set 25 | guiratinga
# Processing Record 30 of Set 25 | bulgan
# Processing Record 31 of Set 25 | arrecife
# Processing Record 32 of Set 25 | nouakchott
# Processing Record 33 of Set 25 | marsh harbour
# Processing Record 34 of Set 25 | karamken
# City not found. Skipping...
# Processing Record 35 of Set 25 | melito di porto salvo
# Processing Record 36 of Set 25 | encruzilhada
# Processing Record 37 of Set 25 | belle fourche
# Processing Record 38 of Set 25 | rongcheng
# Processing Record 39 of Set 25 | nome
# Processing Record 40 of Set 25 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 25 | taoudenni
# Processing Record 42 of Set 25 | altamira
# Processing Record 43 of Set 25 | labuhan
# Processing Record 44 of Set 25 | mnogovershinnyy
# Processing Record 45 of Set 25 | bacolod
# Processing Record 46 of Set 25 | peterhead
# Processing Record 47 of Set 25 | port augusta
# Processing Record 48 of Set 25 | bowen
# Processing Record 49 of Set 25 | muhos
# Processing Record 50 of Set 25 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 26 | boguchany
# Processing Record 2 of Set 26 | abu samrah
# Processing Record 3 of Set 26 | haukipudas
# Processing Record 4 of Set 26 | ulladulla
# Processing Record 5 of Set 26 | santiago
# Processing Record 6 of Set 26 | praxedis guerrero
# Processing Record 7 of Set 26 | sompeta
# Processing Record 8 of Set 26 | almaznyy
# Processing Record 9 of Set 26 | kutum
# Processing Record 10 of Set 26 | kodinsk
# Processing Record 11 of Set 26 | lasa
# Processing Record 12 of Set 26 | chibombo
# Processing Record 13 of Set 26 | yumen
# Processing Record 14 of Set 26 | dinsor
# City not found. Skipping...
# Processing Record 15 of Set 26 | mabaruma
# Processing Record 16 of Set 26 | karymskoye
# Processing Record 17 of Set 26 | merauke
# Processing Record 18 of Set 26 | santa isabel do rio negro
# Processing Record 19 of Set 26 | ranong
# Processing Record 20 of Set 26 | san jeronimo
# Processing Record 21 of Set 26 | pierre
# Processing Record 22 of Set 26 | ayagoz
# Processing Record 23 of Set 26 | montrose
# Processing Record 24 of Set 26 | sarakhs
# Processing Record 25 of Set 26 | miles city
# Processing Record 26 of Set 26 | taft
# Processing Record 27 of Set 26 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 26 | plettenberg bay
# Processing Record 29 of Set 26 | baruun-urt
# Processing Record 30 of Set 26 | saveh
# Processing Record 31 of Set 26 | hope mills
# Processing Record 32 of Set 26 | batagay
# Processing Record 33 of Set 26 | bilibino
# Processing Record 34 of Set 26 | sinnamary
# Processing Record 35 of Set 26 | westfield
# Processing Record 36 of Set 26 | bari
# Processing Record 37 of Set 26 | las tunas
# Processing Record 38 of Set 26 | riaba
# City not found. Skipping...
# Processing Record 39 of Set 26 | manggar
# Processing Record 40 of Set 26 | bayan
# Processing Record 41 of Set 26 | tres lagoas
# Processing Record 42 of Set 26 | puerto leguizamo
# Processing Record 43 of Set 26 | balikpapan
# Processing Record 44 of Set 26 | nanakuli
# Processing Record 45 of Set 26 | kholodnyy
# Processing Record 46 of Set 26 | misasi
# Processing Record 47 of Set 26 | maldonado
# Processing Record 48 of Set 26 | soyo
# Processing Record 49 of Set 26 | salinas
# Processing Record 50 of Set 26 | srednekolymsk
# Processing Record 1 of Set 27 | bara
# Processing Record 2 of Set 27 | victor harbor
# Processing Record 3 of Set 27 | santa cruz cabralia
# Processing Record 4 of Set 27 | depok
# Processing Record 5 of Set 27 | west plains
# Processing Record 6 of Set 27 | evensk
# Processing Record 7 of Set 27 | mundo nuevo
# Processing Record 8 of Set 27 | prainha
# Processing Record 9 of Set 27 | marawi
# Processing Record 10 of Set 27 | la seyne-sur-mer
# Processing Record 11 of Set 27 | hualmay
# Processing Record 12 of Set 27 | aqtobe
# Processing Record 13 of Set 27 | oistins
# Processing Record 14 of Set 27 | codajas
# Processing Record 15 of Set 27 | bonavista
# Processing Record 16 of Set 27 | mount darwin
# Processing Record 17 of Set 27 | bandarbeyla
# Processing Record 18 of Set 27 | riachao do jacuipe
# Processing Record 19 of Set 27 | kysyl-syr
# Processing Record 20 of Set 27 | gwadar
# Processing Record 21 of Set 27 | innisfail
# Processing Record 22 of Set 27 | carbonia
# Processing Record 23 of Set 27 | emba
# Processing Record 24 of Set 27 | berck
# Processing Record 25 of Set 27 | pangnirtung
# Processing Record 26 of Set 27 | alindao
# Processing Record 27 of Set 27 | ulaangom
# Processing Record 28 of Set 27 | trzebnica
# Processing Record 29 of Set 27 | hereford
# Processing Record 30 of Set 27 | nyagan
# Processing Record 31 of Set 27 | srandakan
# Processing Record 32 of Set 27 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 33 of Set 27 | sorong
# Processing Record 34 of Set 27 | toba
# Processing Record 35 of Set 27 | morden
# Processing Record 36 of Set 27 | bandundu
# Processing Record 37 of Set 27 | miandoab
# Processing Record 38 of Set 27 | curuca
# Processing Record 39 of Set 27 | saint-georges
# Processing Record 40 of Set 27 | bethanien
# Processing Record 41 of Set 27 | osa
# Processing Record 42 of Set 27 | novyy urgal
# Processing Record 43 of Set 27 | aykhal
# Processing Record 44 of Set 27 | nikolayevsk-na-amure
# Processing Record 45 of Set 27 | dikson
# Processing Record 46 of Set 27 | katangli
# Processing Record 47 of Set 27 | port hedland
# Processing Record 48 of Set 27 | sobolevo
# Processing Record 49 of Set 27 | payo
# Processing Record 50 of Set 27 | bogo
# Processing Record 1 of Set 28 | nattam
# Processing Record 2 of Set 28 | aksarka
# Processing Record 3 of Set 28 | nanzhou
# Processing Record 4 of Set 28 | madras
# Processing Record 5 of Set 28 | shimoda
# Processing Record 6 of Set 28 | ixtapa
# Processing Record 7 of Set 28 | whitehorse
# Processing Record 8 of Set 28 | phan thiet
# Processing Record 9 of Set 28 | terrace
# Processing Record 10 of Set 28 | inskoy
# Processing Record 11 of Set 28 | lalomanu
# City not found. Skipping...
# Processing Record 12 of Set 28 | waipawa
# Processing Record 13 of Set 28 | serrinha
# Processing Record 14 of Set 28 | durban
# Processing Record 15 of Set 28 | shingu
# Processing Record 16 of Set 28 | basco
# Processing Record 17 of Set 28 | muli
# Processing Record 18 of Set 28 | sungai petani
# Processing Record 19 of Set 28 | tongliao
# Processing Record 20 of Set 28 | fort nelson
# Processing Record 21 of Set 28 | siparia
# Processing Record 22 of Set 28 | san juan
# Processing Record 23 of Set 28 | x-can
# City not found. Skipping...
# Processing Record 24 of Set 28 | muzquiz
# City not found. Skipping...
# Processing Record 25 of Set 28 | juneau
# Processing Record 26 of Set 28 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 28 | maykain
# City not found. Skipping...
# Processing Record 28 of Set 28 | port-cartier
# Processing Record 29 of Set 28 | iquitos
# Processing Record 30 of Set 28 | tucuman
# Processing Record 31 of Set 28 | helong
# Processing Record 32 of Set 28 | atherton
# Processing Record 33 of Set 28 | finnsnes
# Processing Record 34 of Set 28 | katobu
# Processing Record 35 of Set 28 | shancheng
# Processing Record 36 of Set 28 | helesteni harmaneasa
# City not found. Skipping...
# Processing Record 37 of Set 28 | chegdomyn
# Processing Record 38 of Set 28 | maningrida
# Processing Record 39 of Set 28 | nicoya
# Processing Record 40 of Set 28 | ankazoabo
# Processing Record 41 of Set 28 | yerbogachen
# Processing Record 42 of Set 28 | seminole
# Processing Record 43 of Set 28 | ochakiv
# Processing Record 44 of Set 28 | nuziders
# Processing Record 45 of Set 28 | verkhoyansk
# Processing Record 46 of Set 28 | virginia beach
# Processing Record 47 of Set 28 | lyuban
# Processing Record 48 of Set 28 | jinchang
# Processing Record 49 of Set 28 | santo tomas
# Processing Record 50 of Set 28 | amazar
# Processing Record 1 of Set 29 | bud
# Processing Record 2 of Set 29 | domodossola
# Processing Record 3 of Set 29 | venice
# Processing Record 4 of Set 29 | grand baie
# Processing Record 5 of Set 29 | barcelos
# Processing Record 6 of Set 29 | aketi
# Processing Record 7 of Set 29 | laranjeiras do sul
# Processing Record 8 of Set 29 | aldan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)


city_data_df.head(10)
# Out:
#            City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0    Nanortalik  60.1432  -45.2371                snow     23.88        90
# 1      Cidreira -30.1811  -50.2056     overcast clouds     73.92        89
# 2       Rikitea -23.1203 -134.9692     overcast clouds     78.06        76
# 3         Tabou   4.4230   -7.3528       broken clouds     78.87        80
# 4     Carnarvon -24.8667  113.6333           clear sky     91.58        41
# 5       Ushuaia -54.8000  -68.3000          few clouds     38.86        75
# 6  Norman Wells  65.2820 -126.8329          few clouds    -41.76        66
# 7      Bardiyah  31.7561   25.0865    scattered clouds     54.97        64
# 8       Mataura -46.1927  168.8643     overcast clouds     53.47        99
# 9       Magadan  59.5667  150.8000           clear sky     -1.39        74
#
#    Cloudiness  Wind Speed Country
# 0         100       38.63      GL
# 1         100        8.03      BR
# 2         100       16.98      PF
# 3          58        1.77      CI
# 4           6       16.55      AU
# 5          20       10.36      AR
# 6          20        6.91      CA
# 7          46       25.84      LY
# 8         100        2.13      NZ
# 9          10       11.21      RU

# %%
# reorder the columns for better view
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Nanortalik      GL  60.1432  -45.2371     23.88        90         100
# 1      Cidreira      BR -30.1811  -50.2056     73.92        89         100
# 2       Rikitea      PF -23.1203 -134.9692     78.06        76         100
# 3         Tabou      CI   4.4230   -7.3528     78.87        80          58
# 4     Carnarvon      AU -24.8667  113.6333     91.58        41           6
# 5       Ushuaia      AR -54.8000  -68.3000     38.86        75          20
# 6  Norman Wells      CA  65.2820 -126.8329    -41.76        66          20
# 7      Bardiyah      LY  31.7561   25.0865     54.97        64          46
# 8       Mataura      NZ -46.1927  168.8643     53.47        99         100
# 9       Magadan      RU  59.5667  150.8000     -1.39        74          10
#
#    Wind Speed Current Description
# 0       38.63                snow
# 1        8.03     overcast clouds
# 2       16.98     overcast clouds
# 3        1.77       broken clouds
# 4       16.55           clear sky
# 5       10.36          few clouds
# 6        6.91          few clouds
# 7       25.84    scattered clouds
# 8        2.13     overcast clouds
# 9       11.21           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
